# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import sklearn.metrics as sm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('co2.csv')

# %%
df.describe()
# Out:
#            engine     cylandr    fuelcomb        out1
# count  500.000000  500.000000  500.000000  500.000000
# mean     3.600400    6.132000   12.476600  268.026000
# std      1.478191    1.832291    3.943025   67.099673
# min      1.000000    4.000000    4.800000  110.000000
# 25%      2.000000    4.000000    9.500000  217.000000
# 50%      3.600000    6.000000   11.650000  260.000000
# 75%      5.000000    8.000000   14.800000  317.000000
# max      6.800000   12.000000   25.800000  488.000000

# %%
sns.countplot(x='out1' , data=df)
# Out:
# <Axes: xlabel='out1', ylabel='count'>

# %%
plt.subplots(figsize=(3, 3))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
x= df.drop("out1" , axis=1)
x = x.drop("cylandr" , axis=1)
x = x.drop("engine" , axis=1)
y = df.out1

# %%
X_train , X_test , y_train , y_test=train_test_split(x, y, test_size=0.2)

# %%
X_test
# Out:
#      fuelcomb
# 35       12.5
# 150       9.8
# 67       10.3
# 378      16.5
# 380      19.7
# ..        ...
# 495       6.9
# 228      25.8
# 370      12.8
# 428       9.5
# 409       8.5
#
# [100 rows x 1 columns]

# %%
model= linear_model.LinearRegression()

# %%
model.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
y_test_pred = model.predict(X_test)

# %%
plt.scatter(X_test, y_test , color='red')
plt.show()

# %%
plt.scatter(X_test, y_test , color='red')
plt.plot(X_test, y_test_pred, color='black', linewidth=2)
plt.show()

# %%
y_test_pred
# Out:
# array([269.07245465, 229.87199899, 237.13134263, 327.14720379,
#        373.60700309, 232.77573644, 311.17664777, 219.70891789,
#        273.42806084, 219.70891789, 251.65002991, 241.48694881,
#        353.2808409 , 287.94674812, 208.09396806, 205.1902306 ,
#        395.38503402, 210.99770552, 235.6794739 , 273.42806084,
#        203.73836188, 203.73836188, 260.36124228, 327.14720379,
#        213.90144297, 219.70891789, 219.70891789, 242.93881754,
#        327.14720379, 354.73270962, 229.87199899, 318.43599142,
#        248.74629245, 391.02942783, 203.73836188, 200.83462442,
#        184.86406841, 327.14720379, 287.94674812, 192.12341205,
#        314.08038523, 287.94674812, 296.65796049, 258.90937355,
#        341.66589107, 187.76780586, 174.70098731, 251.65002991,
#        266.16871719, 264.71684847, 256.0056361 , 315.53225396,
#        215.3533117 , 241.48694881, 270.52432338, 229.87199899,
#        244.39068627, 208.09396806, 218.25704916, 203.73836188,
#        399.7406402 , 234.22760517, 287.94674812, 414.25932749,
#        245.842555  , 229.87199899, 205.1902306 , 377.96260928,
#        219.70891789, 245.842555  , 250.19816118, 301.01356668,
#        192.12341205, 348.92523471, 157.27856257, 234.22760517,
#        301.01356668, 222.61265534, 322.7915976 , 253.10189864,
#        241.48694881, 271.97619211, 219.70891789, 215.3533117 ,
#        282.13927321, 232.77573644, 373.60700309, 399.7406402 ,
#        311.17664777, 266.16871719, 234.22760517, 215.3533117 ,
#        289.39861685, 250.19816118, 282.13927321, 187.76780586,
#        462.17099552, 273.42806084, 225.5163928 , 210.99770552])
